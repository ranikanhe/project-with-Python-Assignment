# %% [markdown]
# <a href="https://colab.research.google.com/github/ranikanhe/project-with-Python-Assignment/blob/main/2_String_in_python_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Practice

# %%
sen="Parth Is a Data Analyst"
sen[3]
# Out:
# 't'

# %% [markdown]
# 1 Write a Python program that accepts a string from user. Your program should create and display a new string where the first and last characters have been exchanged.
#
# For example if the user enters the string 'HELLO' then new string would be 'OELLH'

# %%
string = input("Enter a String = ")

first = string[0]
last = string[-1]
mid = string[1:-1]

print(last, mid, first)
# Out:
# Enter a String = HELLO
# O ELL H

# %%
string=input("Enterv a string=")
first=string[0]
last=string[-1]
mid=string[1:-1]
print(last+mid+first)

# %% [markdown]
# Q2 Write a Python program that accepts a string from user. Your program should create a new string in reverse of first string and display it.
#
# For example if the user enters the string 'EXAM' then new string would be 'MAXE'

# %%
my_string=input("Enter String =")
reversed_string=my_string[::-1]
print(reversed_string)
# Out:
# Enter String =EXAM
# MAXE

# %% [markdown]
# Q3 Write a Python program that accepts a string from user. Your program should create a new string by shifting one position to left.
#
# For example if the user enters the string 'examination 2021' then new string would be 'xamination 2021e'

# %%
my_string=input("enter a string")
first=my_string[0]
second=my_string[1:]
print(second+first)
# Out:
# enter a stringexamination2021
# xamination2021e

# %% [markdown]
# Q4 Write a Python program to calculate the length of a string.

# %%
my_string=input("Enter String =")
print(len(my_string))
# Out:
# Enter String =rani
# 4

# %% [markdown]
# Q5 Write a Python program to get a string made of the first 2 and last 2 characters of a given string. If the string length is less than 2, return the empty string instead.
# Sample String : 'w3resource'
# Expected Result : 'w3ce'
# Sample String : 'w3'
# Expected Result : 'w3w3'
# Sample String : ' w'
# Expected Result : Empty String

# %%
my_string=input("enter string =")
first=my_string[:2]
last=my_string[-2:]
if len(my_string) < 2:
 print("empty")
else:
   print(first+last)
# Out:
# enter string =ranikanhe
# rahe

# %% [markdown]
# Q6 Write a Python program to add 'ing' at the end of a given string (length should be at least 3). If the given string already ends with 'ing', add 'ly' instead. If the string length of the given string is less than 3, leave it unchanged.
# Sample String : 'abc'
# Expected Result : 'abcing'
# Sample String : 'string'
# Expected Result : 'stringly'

# %%
# Take input from the user
s = input("Enter a string: ")

# Check the string length
if len(s) < 3:
    result = s
elif s.endswith("ing"):
    result = s + "ly"
else:
    result = s + "ing"

# Display result
print("Result:", result)
# Out:
# Enter a string: rani
# Result: raniing

# %% [markdown]
# Q7 Write a Python program to remove the nth index character from a nonempty string.

# %%
s = input("ENter a string = ") #abhishek = 8
n = int(input("Enter index number = ")) # = 9
# if len(s) > n:
start = s[:n]
end = s[n+1 :]
print(start+end)
# else:
#   print("Invalid Input")
# Out:
# ENter a string = rani
# Enter index number = 3
# ran

# %% [markdown]
# Q8 Write a Python program to change a given string to a newly string where the first and last chars have been exchanged.

# %%
string= input("Enter a String =")

# if len(string) < 2:
#     print("String too short to swap!")
# else:
first = string[0]
last= string[-1]
mid = string [1 : -1]
print(last + mid + first)
# Out:
# Enter a String =ranikanhe
# eanikanhr

# %% [markdown]
# Q9 Write a Python script that takes input from the user and displays that in upper and lower cases.

# %%
text = input("Enter any text: ")

print("Upper case:", text.upper())
print("Lower case:", text.lower())
# Out:
# Enter any text: rani
# Upper case: RANI
# Lower case: rani
